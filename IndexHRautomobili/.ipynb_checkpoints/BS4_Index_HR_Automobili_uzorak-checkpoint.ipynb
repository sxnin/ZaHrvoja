# %% [markdown]
# ### Imports-uvoz potrebnih modula za projekt

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
from dataclasses import dataclass, asdict

# %%
@dataclass
class Car:
    naslov: str
    godiste: int
    kilometri: str
    snagakW: int
    lokacija: str
    cijena_kn: int
    cijena_Eur: int

# %% [markdown]
# ### HTTP Request-zahtjev

# %% [markdown]
# #### spremanje poveznice/linka, unutar varijable 'webstranica'

# %%
webstranica = "https://www.index.hr/oglasi/osobni-automobili/gid/27?pojamZup=-2&tipoglasa=1&grad=0&naselje=0&cijenaod=0&cijenado=46394055&num=200&elementsNum=50&sortby=1"

# %% [markdown]
# ### Get Request
# #### Spremanje unutar varijable  'povrat' web stranice uz pomoć zahtjeva .get kroz requests modul

# %%
povrat = requests.get(webstranica)

# %% [markdown]
# ### Status Code
# #### Provjera statusnog koda-važno nam je radi eventualne prilagodbe ako ima problema
# #### sa zahtjevom HTTP tipa 404 ili 500 itd što spada pod error

# %%
povrat.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Objekt
# #### Kreiranje 'soup' objekta da bi dobili HTML elemente prertodno kreirane varijable 'povrata' ciljane web stranice

# %%
soup = BeautifulSoup(povrat.content, 'html.parser')   # za kreiranje objekta tribam dva argumenta, sadržaj povrata i 'html raščlanjivač'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="1697489853797759" property="fb:app_id"/>
# <title>Rabljena vozila na prodaju | Auto-moto oglasnik</title>
# <meta content="Rabljena vozila na prodaju | Auto-moto oglasnik" property="og:title"/>
# <meta content="https://www.index.hr/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=200&amp;elementsNum=50&amp;sortby=1" property="og:url"/>
# <meta content="Pitate se gdje kupiti auto? Ovo je najveća baza rabljenih automobila u Hrvatskoj! Pretražite oglase, saznajte cijenu i pogledajte slike. – Index Oglasi." name="description"/>
# <meta content="www.index.hr/oglasi" property="og:site_name"/>
# <link href="https://www.index.hr/oglasi/osobni-automobili/gid/27" rel="canonical"/>
# <meta content="https://www.index.hr/oglasi/img/IndexOglasiLogo.jpg" property="og:image"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=3.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection">
# <link href="https://www.index.hr/oglasi/favicon.ico" rel="SHORTCUT ICON" type="image/ico"/>
# <link href="https://www.index.hr/oglasi/favicon.png" rel="icon" type="image/png"/>
# <style>
#
# @charset "UTF-8";.selectator *,html{box-sizing:border-box}ul,ul li{list-style-type:none}.clearfix,.row:after{clear:both}nav,nav a,nav ul a{color:#fff}.btn,.progress{background-clip:padding-box}.btn,.selectator,.selectator *,a{text-decoration:none}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Light-webfont.svg#robotolight) format('svg');font-weight:300;font-style:normal}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Regular-webfont.svg#robotothin) format('svg');font-weight:400;font-style:normal}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Medium-webfont.svg#robotobold) format('svg');font-weight:500;font-style:normal}@font-face{font-family:Roboto;src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.eot);src:url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.eot?#iefix) format('embedded-opentype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.woff) format('woff'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.ttf) format('truetype'),url(https://www.index.hr/oglasi/font/roboto/Roboto-Bold-webfont.svg#robotobold) format('svg');font-weight:700;font-style:normal}@font-face{font-family:font-ioglasi;src:url(https://www.index.hr/oglasi/font/ikone/icons5.eot);src:url(https://www.index.hr/oglasi/font/ikone/icons5.eot?#iefix) format("embedded-opentype"),url(https://www.index.hr/oglasi/font/ikone/icons5.woff) format("woff"),url(https://www.index.hr/oglasi/font/ikone/icons5.ttf) format("truetype"),url(https://www.index.hr/oglasi/font/ikone/icons5.svg#font-ioglasi) format("svg");font-weight:400;font-style:normal}[class*=" icon-"]:before,[class^=icon-]:before{font-family:font-ioglasi!important;font-style:normal!important;font-weight:400!important;font-variant:normal!important;text-transform:none!important;speak:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon-auto-moto-menu:before{content:"\66"}.icon-menu:before{content:"\75"}.icon-nekretnine-menu:before{content:"\41"}.icon-plus-mob:before{content:"\43"}.icon-poslovi-menu:before{content:"\45"}.icon-turizam-menu:before{content:"\4c"}.icon-usluge-menu:before{content:"\4f"}.icon-zoom:before{content:"\50"}.icon-arrow-down-menu:before{content:"\62"}.icon-korisnik:before{content:"\73"}.icon-close:before{content:"\51"}.icon-odjeca-menu:before{content:"\23"}.icon-strojevi-menu:before{content:"\24"}.icon-zivotinje-menu:before{content:"\26"}.icon-sve-za-kucu-menu:before{content:"\3d"}.icon-informatika-1-menu:before{content:"\5b"}.icon-stvari-menu:before{content:"\5e"}.icon-foto-menu:before{content:"\60"}.icon-sport-menu:before{content:"\40"}html{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}header,nav{display:block}a{background-color:transparent}img{border:0}button,input,select{color:inherit;font:inherit;m ...
#
# 		</style>
# <link href="/oglasi/css/myCss?v=XUHcq_UrL8P2SWA_4haN86YEtX1CL9l4pUnVjbTuBkc1" rel="stylesheet" type="text/css"/>
# <link href="/favicon.png" rel="icon" type="image/png"/>
# <script src="https://www.index.hr/oglasi/js/prebid4.15.0.js"></script>
# <script data-cfasync="false" type="text/javascript">(function(w, d) { var s = d.createElement("script"); s.src = "//delivery.adrecover.com/43137/adRecover.js"; s.type = "text/javascript"; s.async = true; (d.getElementsByTagName("head")[0] || d.getElementsByTagName("body")[0]).appendChild(s); })(window, document);</script>
# <script>
#
# 				var adUnits = [];
#
# 				var sizes = [
# 					[300, 250]
# 				];
# 				var PREBID_TIMEOUT = 1000;
# 				var CURRENCY_RATE = 0.86;
#                 var CONSENT_TIMEOUT = 1000;
# 				var pbjs = pbjs || {};
# 				pbjs.que = pbjs.que || [];
# 				var FAILSAFE_TIMEOUT = 3000;
#
#
#
#
# 					//div-gpt-ad-1488896278673-0
# adUnits.push({
# 	code: 'div-gpt-ad-1488896278673-0',
# 	mediaTypes: {
# 		banner: {
# 			sizes: [[300, 250], [300, 600]]
# 		}
# 	},
# 	bids: [{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'rubicon',
# 		params: {
# 			accountId: '16666',
# 			siteId: '141496',
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'ix',
# 		params: {
# 			siteId: '299060',
# 			size: [300, 250]
# 		}
#      },{
# 		bidder: 'ix',
# 		params: {
# 			siteId: '299060',
# 			size: [300, 600]
# 		}
#      },{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918664'
# 		}
# 	},{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918667'
# 		}
# 	}]
# });
#
# 								 <!--Old 26.11.2021-9-05-->
#                                 //div-gpt-ad-1637581619420-0
# adUnits.push({
# 	code: 'div-gpt-ad-1637581619420-0',
# 	mediaTypes: {
# 		banner: {
# 			sizes: [300, 250]
# 		}
# 	},
# 	bids: [{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'rubicon',
# 		params: {
# 			accountId: '16666',
# 			siteId: '141496',
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'ix',
# 		params: {
# 			siteId: '299061',
# 			size: [300, 250]
# 		}
#      },{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918674'
# 		}
# 	},{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918675'
# 		}
# 	},{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918679'
# 		}
# 	}]
# });
#
#
# 								//div-gpt-ad-1536147600586-0
# adUnits.push({
# 	code: 'div-gpt-ad-1536147600586-0',
# 	mediaTypes: {
# 		banner: {
# 			sizes: [300, 250]
# 		}
# 	},
# 	bids: [{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'rubicon',
# 		params: {
# 			accountId: '16666',
# 			siteId: '141496',
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'ix',
# 		params: {
# 			siteId: '299059',
# 			size: [300, 250]
# 		}
#      },{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918660'
# 		}
# 	}]
# });
#
# 								//div-gpt-ad-1536147707699-0
# adUnits.push({
# 	code: 'div-gpt-ad-1536147707699-0',
# 	mediaTypes: {
# 		banner: {
# 			sizes: [300, 250]
# 		}
# 	},
# 	bids: [{
# 		bidder: 'criteo',
# 		params: {
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'rubicon',
# 		params: {
# 			accountId: '16666',
# 			siteId: '141496',
# 			networkId: '10721'
# 		}
#      },{
# 		bidder: 'ix',
# 		params: {
# 			siteId: '299059',
# 			size: [300, 250]
# 		}
#      },{
# 		bidder: 'appnexus',
# 		params: {
# 			placementId: '13918660'
# 		}
# 	}]
# });
#
#
#
#
#
#
#
#
#
# 			</script>
# <script>
#
#
# 				pbjs.que = pbjs.que || [];
#
# 				pbjs.bidderSettings = {
# 					rubicon: {
# 						bidCpmAdjustment: function (bidCpm) {
# 							return bidCpm * CURRENCY_RATE;
# 						}
# 					},
# 					criteo: {
# 						bidCpmAdjustment: function (bidCpm) {
# 							return bidCpm * CURRENCY_RATE;
# 						}
# 					},
# 					ix: {
# 						bidCpmAdjustment: function (bidCpm) {
# 							return bidCpm * CURRENCY_RATE;
# 						}
# 					},
# 					appnexus: {
# 						bidCpmAdjustment: function (bidCpm) {
# 							return bidCpm * CURRENCY_RATE;
# 						}
# 					}
# 				};
#
# 				const customPrebidGranularity = {
# 					"buckets": [
# 						{
# 							"min": 0,
# 							"max": 100,
# 							"increment": 0.1
# 						}
# 					]
# 				};
# 				//pbjs.setConfig({
# 				//	debug: true,
# 				//	priceGranularity: customPrebidGranularity,
# 				//	enableSendAllBids: true
# 				//});
#
# 				var googletag = googletag || {};
# 				googletag.cmd = googletag.cmd || [];
# 				googletag.cmd.push(function () {
# 					googletag.pubads().disableInitialLoad();
# 				});
#
# 			    window.didomiEventListeners = window.didomiEventListeners || [];
# 			    window.didomiEventListeners.push({
# 			        event: 'integrations.consentpassedtodfp',
# 			        listener: function (data) {
# 			            // Consent has been passed to Google
# 			            // Load or refresh ads as needed with DFP, Prebid, etc.
# 			            // `data.consentStatus` contains the current consent status of the user (true/false/undefined)
# 			            // `data.index` contains the index of the event (integer)
# 			            if (data.index === 0) {
# 			                // This is the very first event on the page that gets triggered on page load
# 			                initializeGoogletagRefreshWithPrebid();
# 			            } else {
# 			                // This is an event that happens later on the page, after a user action (user giving consent or changing their preferences)
# 			                //googletag.pubads().refresh();
# 			            }
# 			        }
# 			    });
#
# 			    function initializeGoogletagRefreshWithPrebid() {
# 			        pbjs.que.push(function () {
#
# 			            pbjs.setConfig({
# 			                consentManagement: {
# 			                    cmpApi: 'iab',
# 			                    timeout: CONSENT_TIMEOUT,
# 			                    allowAuctionWithoutConsent: true,
# 			                    defaultGdprScope: true
# 			                },
# 			                //debug: true,
# 			                userSync: {
# 			                    filterSettings: {
# 			                        iframe: {
# 			                            bidders: '*',      // '*' represents all bidders
# 			                            filter: 'include'
# 			                        }
# 			                    }
# 			                },
# 			                priceGranularity: customPrebidGranularity,
# 			                enableSendAllBids: true
# 			            });
#
# 			            pbjs.addAdUnits(adUnits);
# 			            pbjs.requestBids({
# 			                bidsBackHandler: sendAdserverRequest,
# 			                timeout: PREBID_TIMEOUT
# 			            });
# 			        });
# 			    }
#
#
#
# 			    function sendAdserverRequest() {
# 			        if (pbjs.adserverRequestSent) return;
# 			        pbjs.adserverRequestSent = true;
# 			        googletag.cmd.push(function () {
# 			            pbjs.que.push(function () {
#
# 			                var pbInterval = setInterval(function () {
#
# 			                    //when ads are available, refresh it
# 			                    if (googletag.pubads().getSlots().length > 0) {
# 			                        clearInterval(pbInterval); //clear interval for ad render (should trigger only once)
# 			                        pbjs.setTargetingForGPTAsync();
#
# 			                        googletag.pubads().refresh();
# 			                    }
#
# 			                }, 10);
# 			            });
# 			        });
# 			    }
#
# 			    //in case PBJS doesn't load
# 			    setTimeout(function () {
# 			        sendAdserverRequest();
# 			    }, FAILSAFE_TIMEOUT);
#
# 			</script>
# <script type="text/javascript">
# 				window.gdprAppliesGlobally = true; (function () {
# 					function a(e) {
# 						if (!window.frames[e]) {
# 							if (document.body && document.body.firstChild) { var t = document.body; var n = document.createElement("iframe"); n.style.display = "none"; n.name = e; n.title = e; t.insertBefore(n, t.firstChild) }
# 							else { setTimeout(function () { a(e) }, 5) }
# 						}
# 					} function e(n, r, o, c, s) {
# 						function e(e, t, n, a) { if (typeof n !== "function") { return } if (!window[r]) { window[r] = [] } var i = false; if (s) { i = s(e, t, n) } if (!i) { window[r].push({ command: e, parameter: t, callback: n, version: a }) } } e.stub = true; function t(a) {
# 							if (!window[n] || window[n].stub !== true) { return } if (!a.data) { return }
# 							var i = typeof a.data === "string"; var e; try { e = i ? JSON.parse(a.data) : a.data } catch (t) { return } if (e[o]) { var r = e[o]; window[n](r.command, r.parameter, function (e, t) { var n = {}; n[c] = { returnValue: e, success: t, callId: r.callId }; a.source.postMessage(i ? JSON.stringify(n) : n, "*") }, r.version) }
# 						}
# 						if (typeof window[n] !== "function") { window[n] = e; if (window.addEventListener) { window.addEventListener("message", t, false) } else { window.attachEvent("onmessage", t) } }
# 					} e("__tcfapi", "__tcfapiBuffer", "__tcfapiCall", "__tcfapiReturn"); a("__tcfapiLocator"); (function (e) {
# 						var t = document.createElement("script"); t.id = "spcloader"; t.type = "text/javascript"; t.async = true; t.src = "https://sdk.privacy-center.org/" + e + "/loader.js?target=" + document.location.hostname; t.charset = "utf-8"; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(t, n)
# 					})("02757520-ed8b-4c54-8bfd-4a5f5548de98")
# 				})();
# 			</script>
# <script async="" data-vendor="didomi:google" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="didomi/javascript"></script>
# <script type="text/javascript">
#
# 			var approot='https://www.index.hr/oglasi/';
#
# 			if(document.location.href.indexOf("http://dev3/") > - 1){
# 				approot = approot.replace("https:", "http:");
# 			}
#
# 			var appProtocol = 'https';
# 			var korIme = '';
# 			var isItMobile = false;
#
# 			var addthis_config = {
# 			services_exclude: 'zingme,ziczac,zakladoknet,yuuby,yummly,youmob,yorumcuyum,yoolink,yookos,yammer,yahoomail,xing,wykop,wordpress,wishmindr,domaintoolswhois,wechat,sharer,weheartit,internetarchive,wanelo,vybralisme,voxopolis,vkrugudruzei,vk,visitezmonsite,virb,viadeo,venmo,urlaubswerkde,typepad,tumblr,tuenti,trello,thisnext,tencentweibo,tencentqq,taringa,symbaloo,svejo,surfingbird,supbro,stumpedia,stumbleupon,stuffpit,studivz,startlap,startaid,spinsnap,sodahead,sms,smiru,slack,skyrock,skype,sinaweibo,scoopit,safelinking,retellity,researchgate,renren,rediff,reddit,qzone,quantcast,qrsrc,pusha,printfriendly,posteezy,pocket,plurk,pinterest_share,pinboard,pdfmyurl,paypalme,patreon,pafnetde,oyyla,hotmail,openthedoor,onenote,oknotizie,odnoklassniki_ru,nurses_lounge,nujij,newsvine,newsmeback,netvouz,netvibes,naszaklasa,n4g,myvidster,myspace,mrcnetworkit,moemesto,mixi,meneame,mendeley,memori,memonic,meinvz,markme,margarin,mymailru,livejournal,linkuj,lineme,lidar,kledy,kindleit,ketnooi,kakaotalk,kakao,kaixin,jappy,iorbix,instapaper,indexor,w3validator,houzz,hootsuite,historious,hedgehogs,hatena,hackernews,google_plusone_share,googletranslate,google_classroom,google,govn,gmail,gg,thefreedictionary,folkd,flipboard,financialjuice,favoritus,favorites,faves,favable,fashiolista,thefancy,informazione,facenama,fabulously40,stylishhome,exchangle,evernote,mailto,email,edcast,draugiem,douban,diigo,diggita,digg,diary_ru,cssbased,cosmiq,link,technerd,cloob,cleansave,cleanprint,citeulike,cashme,care2,camyoo,buffer,box,bookmerkende,bookmarkycz,bonzobox,bobrdobr,blogmarks,blogkeen,blogger,bland,bizsugar,bitly,beat100,balatarin,baidu,atavi,apsense,aolmail,aim,amenme,amazonsmile,amazonwishlist,advqr,adifni,adfty,addressbar,100zakladok,pinterest,google_plusone,foursquare'
# 			};
#
#
#
#
# 				var tecajNet = 0;
# 				var tmpDaLiMozeBitiNulaKn = false;
# 				var ajaxPopulateData = "";
# 				var kojaGlavnaKategorijaID = 0;
#
#
#
# 			var OA_zones = {
# 				"Billboard" : 5,
# 				"Wallpaper" : 3,
# 				"300x250A" : 6,
# 				"300x250B" : 7,
# 				"300x250C" : 8,
# 				"300x250D" : 16,
# 				"675x90A" : 9,
# 				"675x90B" : 10,
# 				"675x90C" : 11,
# 				"675x90D" : 17,
# 				"Header" : 15,
# 				"300x250DnoNaslovnice" : 37
# 			};
#
# 			var tmpIsMobileTs = "False";
#
# 		</script>
# <!-- DO NOT MODIFY -->
# <!-- End Facebook Pixel Code -->
# </meta></head>
# <body class="ads-visible" data-protocol="https">
# <div id="overlayForImgUpload"><img alt="Upload" src="https://www.index.hr/oglasi/img/36.gif"/>
# <div class="progress">
# <div id="progressbar"></div>
# </div>
# </div>
# <header>
# <div class="header">
# <div class="header_logo"><a class="logo" href="https://www.index.hr/oglasi/"></a></div>
# <div class="header_search">
# <div class="search_wrapper">
# <div class="search_container">
# <form action="https://www.index.hr/oglasi/rezultat-pretrage" id="pojamForm" method="GET" name="pojam">
# <div class="search">
# <div class="search_fields">
# <div class="search_form">
# <input autocomplete="off" class="searchbox" name="pojam" placeholder="Upišite pojam..." type="text" value=""/>
# <div class="search_drop hide-on-med-and-down">
# <select class="select_replacement" data-tag="Županija" id="sliding_zupanije" name="pojamZup">
# <option selected="" value="-2">Sve Županije</option>
# <option value="-1">Izvan Hrvatske</option>
# <option value="1150">Bjelovarsko-bilogorska</option>
# <option value="1151">Brodsko-posavska</option>
# <option value="1152">Dubrovačko-neretvanska</option>
# <option value="1153">Grad Zagreb</option>
# <option value="1154">Istarska</option>
# <option value="1155">Karlovačka</option>
# <option value="1156">Koprivničko-križevačka</option>
# <option value="1157">Krapinsko-zagorska</option>
# <option value="1158">Ličko-senjska</option>
# <option value="1159">Međimurska</option>
# <option value="1160">Osječko-baranjska</option>
# <option value="1161">Požeško-slavonska</option>
# <option value="1162">Primorsko-goranska</option>
# <option value="1163">Sisačko-moslavačka</option>
# <option value="1164">Splitsko-dalmatinska</option>
# <option value="1165">Šibensko-kninska</option>
# <option value="1166">Varaždinska</option>
# <option value="1167">Virovitičko-podravska</option>
# <option value="1168">Vukovarsko-srijemska</option>
# <option value="1169">Zadarska</option>
# <option value="1170">Zagrebačka</option>
# </select>
# </div>
# </div>
# </div>
# <div class="search_btn">
# <button class="icon-zoom" type="submit"></button>
# </div>
# </div>
# <a class="icon-close hide-on-med-and-up" href="javascript:;"></a>
# </form>
# </div>
# <div class="predaj_oglas hide-on-small-only">
# <a class="btn btn-empty-white" href="https://www.index.hr/oglasi/login.aspx?predaj=true">Predaj oglas besplatno</a>
# </div>
# </div>
# </div>
# <div class="header_icons hide-on-med-and-up">
# <a class="icon-zoom" href="#" id="show_search_on_small"></a>
# <a class="icon-plus-mob" href="https://www.index.hr/oglasi/login.aspx?predaj=true"></a>
# <a class="icon-korisnik" href="https://www.index.hr/oglasi/login.aspx"></a>
# </div>
# <div class="header_myAccount hide-on-small-only">
# <a class="notlogged" href="https://www.index.hr/oglasi/login.aspx?action=registracija">Registracija</a>
# <a class="notlogged" href="https://www.index.hr/oglasi/login.aspx">Prijava</a>
# </div>
# <div class="header_menu"><a class="button-collapse icon-menu" data-activates="slide-out" href="#"></a></div>
# </div>
# <div class="myAccount_menu">
# <div class="arrow_up"><span>▲</span></div>
# <div class="wrapper">
# <div class="menu">
# <ul>
# <li><a href="https://www.index.hr/oglasi/login.aspx?action=registracija">Registracija</a></li>
# <li><a href="https://www.index.hr/oglasi/login.aspx">Prijava</a></li>
# </ul>
# </div>
# </div>
# </div>
# </header>
# <script type="text/javascript">
# 			try{
# 				OA_show('Billboard');
# 			}catch(ex){
# 				//
# 			}
# 		</script>
# <div class="nav_container">
# <nav>
# <ul class="side-nav collapsible" data-collapsible="accordion" id="slide-out">
# <li class="heading">
# <div>Kategorije<a class="icon-close" href="javascript:;"></a></div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-auto-moto-menu"></span>
# Auto-moto
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/27">Osobni automobili</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/28">Motocikli  i skuteri</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/29">Gospodarska vozila</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/30">Kamperi i kamp prikolice</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/31">Tražena vozila</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/32">Dijelovi i dodatci</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/3322">Oldtimeri</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/auto-moto/gid/13315">Čišćenje i održavanje vozila</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-nekretnine-menu"></span>
# Nekretnine
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/423">Kuće</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/424">Stanovi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/425">Zemljišta</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/426">Novogradnja</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/427">Poslovni prostori</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/428">Garaže</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/429">Nekretnine za odmor</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/431">Dvorane</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/432">Ostalo vezano uz nekretnine</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/843">Domski i studentski smještaj</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/13189">Umirovljenički smještaj</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/13216">Najam soba</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nekretnine/gid/13382">Parkirna mjesta</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-poslovi-menu"></span>
# Poslovi
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13285">Arhitektura, graditeljstvo i geodezija</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13286">Administracija</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13287">Bankarstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13288">Dizajn i umjetnost</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13289">Elektrotehnika</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13290">Farmacija</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13291">Ekonomija, financije, računovodstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13292">Graditeljstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13293">Instalacije, održavanje i popravak</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13294">IT</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13295">Ljepota</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13296">Management</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13297">Marketing i mediji</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13298">Obrazovanje i znanost</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13299">Poljoprivreda, šumarstvo i ribarstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13300">Prodaja</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13301">Proizvodnja i zanatske usluge</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13302">Promet</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13303">Skladištenje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13304">Skrb i njega</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13305">Turizam i ugostiteljstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13306">Zdravstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13312">Ostali poslovi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/poslovi/gid/13387">Trgovina</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-zivotinje-menu"></span>
# Životinje
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/361">Ljubimci na prodaju</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/362">Udomljavanje i poklanjanje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/363">Oprema i dodatci</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/376">Nestali, izgubljeni i nađeni</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/936">Životinje za parenje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/937">Prehrana</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/938">Veterinari, šetači i vezane usluge</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/939">Domaće životinje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/zivotinje/gid/940">Ostalo vezano uz životinje</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-stvari-menu"></span>
# Stvari
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/394">Zabava</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/395">Literatura</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/396">Glazbeni instrumenti i oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/397">Uredska oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/398">Ostale stvari</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/806">Medicinska oprema i pomagala</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/831">Staro i vrijedno</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13183">Zabavni Aparati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13224">Ljepota</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13270">Izgubljeno i nađeno</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13273">Zdravlje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13326">Materijal i oprema za umjetnost</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13373">Oprema za frizerski salon</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/stvari/gid/13390">Zaštita na radu</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-usluge-menu"></span>
# Usluge
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/433">Serviserske usluge</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/434">Ljepota i zdravlje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/435">Obrtništvo i gradnja</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/436">Usluge vezane uz kuću i dom</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/437">Poduke i instrukcije</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/438">Dizajn, fotografiranje i intelektualne usluge</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/440">Proslave i organizacija događaja</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/441">Ostale usluge</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/925">Sve za vjenčanja i slično</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/13235">Iznajmljivanje vozila</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/usluge/gid/13391">Prevoditeljske usluge</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-turizam-menu"></span>
# Turizam
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/844">Privatni smještaj u Hrvatskoj</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/845">Putovanja i putni aranžmani</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/846">Hrana, piće i domaći pripravci</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/847">Ostalo vezano uz turizam i gastronomiju</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/848">Gastro ponuda</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/3588">Domaći hoteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/turizam/gid/3595">Skijanje i zimovanje</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-foto-menu"></span>
# Audio, video, foto
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/463">TV, video i oprema za satelitsku</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/464">Foto</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/469">Navigacija i akustika za vozila</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/470">MP3, MP4, iPod playeri i oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/471">Radio stanice i radio-amaterska oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/473">Audio komponente i oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/audio-i-video/gid/494">Ostalo za audio i video</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-odjeca-menu"></span>
# Odjeća i obuća
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/641">Odjeća</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/642">Obuća</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/645">Torbe i novčanici</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/646">Naočale</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/647">Nakit</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/648">Satovi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/649">Ostalo vezano uz odjeću i stil</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/13232">Modni dodatci</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/odjeca-i-obuca/gid/13314">Sve za šivanje</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-informatika-1-menu"></span>
# Informatika
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/681">Softver i profesionalni programi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/684">PC računala i komponente</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/685">Mrežna oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/686">Wi-fi wireless oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/688">MAC</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/689">USB prijenosna memorija i uređaji</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/690">Prijenosna računala - laptopi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/691">Memorije i čitači</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/692">Igrice i igraće konzole</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/693">Ostala informatička oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/709">Miševi, tipkovnice i slično</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/983">Monitori</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/984">Tablet računala</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/13182">Domaći software</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/13192">Printeri, skeneri i fotokopirni aparati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/racunala-programi-i-dodatci/gid/13368">Web stranice</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-sve-za-kucu-menu"></span>
# Sve za dom
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/387">Kućanski aparati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/625">Namještaj</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/764">Sve za vrt i balkon</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/765">Posuđe i pribor za kuhanje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/766">Kućanski tekstil</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/767">Tepisi i sagovi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/768">Rasvjeta</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/769">Grijanje i hlađenje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/770">Građenje i opremanje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/771">Sigurnost doma</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/772">Ostalo vezano uz dom</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sve-za-kucu-i-dom/gid/13375">Dekoracije za dom</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-sport-menu"></span>
# Sport i oprema
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/710">Airsoft i paintball oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/712">Oprema za alpinizam i planinarenje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/713">Bicikli i biciklistička oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/714">Oprema za borilačke sportove</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/715">Dodatci prehrani i oprema za vježbanje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/716">Oprema za sport i fitness</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/717">Oprema za kampiranje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/719">Oružje i oprema za lov</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/721">Ostalo vezano uz sport i slobodno vrijeme</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/739">Role i oprema za rolanje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/740">Oprema za tenis</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/741">Oprema za vodene sportove</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/742">Oprema za zimske sportove</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/13185">Nogomet i nogometna oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/13214">Ribolovni pribor i oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/sport-i-slobodno-vrijeme/gid/13328">Sportski dresovi i slično</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-strojevi-menu"></span>
# Strojevi i alati
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3230">Poljoprivredni strojevi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3241">Građevinski strojevi i alati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3249">Viličari, platforme i oprema za visinske radove</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3250">Strojevi i alati za komunalnu djelatnost</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3252">Obradni strojevi i alati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3265">Strojevi i oprema za šumarstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3266">Mjerni instrumenti</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3267">Električni uređaji i alati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3268">Ručni alati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/3269">Ugostiteljska i trgovačka oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/13215">Elektronski uređaji i aparati</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/13236">Strojevi i alati za obradu kamena</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/13316">Strojevi za industrijsko čišćenje</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/strojevi-i-alati/gid/13374">Ostali strojevi i alati</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-nautika-menu"></span>
# Nautika
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/3566">Plovila</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/3567">Charter</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/3568">Nautička oprema</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/3569">Brodski motori</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/3570">Brodski rezervni dijelovi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/3571">Prikolica za plovila</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/nautika/gid/13284">Ostalo vezano uz nautiku</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-mobitel-menu"></span>
# Mobiteli
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3446">Alcatel</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3447">Blackberry</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3448">HTC</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3449">Huawei</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3450">iPhone</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3451">Lenovo mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3452">LG mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3453">Prestigio</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3454">Samsung mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3455">Siemens mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3457">Sony mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3458">Sony Ericsson mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3459">ZTE mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3461">Oprema i dijelovi za mobitele</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3462">Ostali mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3463">Ostalo vezano uz mobitele</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3464">Microsoft mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3500">Nokia mobiteli</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/3565">Fiksni telefoni</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/13365">Nexus</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/mobiteli/gid/13366">Motorola</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-djecji-svijet-menu"></span>
# Dječji svijet
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/djecji-svijet/gid/644">Dječja robica</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/djecji-svijet/gid/753">Igračke i oprema za djecu</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-ostalo-menu"></span>
# Ostalo
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13319">Grobnice</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13321">Stočna hrana</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13322">Karte i ulaznice</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13323">Ostalo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13324">Modelarstvo i maketarstvo</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13325">Sakupljačka strast</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/ostalo/gid/13347">Događanja</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="collapsible-header">
# <span class="cat_icon icon-phs-menu"></span>
# Domaći proizvodi
# <span class="cat_arrow icon-arrow-down-menu"></span>
# </div>
# <div class="collapsible-body">
# <ul>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13337">Kruh i slastice</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13338">Med i proizvodi od meda</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13339">Mliječni proizvodi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13340">Povrće i voće</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13341">Cvijeće</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13342">Prerađevine od voća i povrća</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13343">Meso i suhomesnati proizvodi</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13344">Ulje i ocat</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13345">Vino i rakije</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13346">Domaći proizvodi - razno</a>
# </li>
# <li>
# <a data-f="1" href="https://www.index.hr/oglasi/proizvodi-hrvatskog-sela/gid/13357">Gljive, plodovi i sjemenke</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="clearfix"></div>
# </nav>
# </div>
# <div class="breadcrumbs hide-on-med-and-down">
# <div class="container" xmlns:v="https://rdf.data-vocabulary.org/#">
# <ul id="bread" itemprop="breadcrumb">
# <li typeof="v:Breadcrumb"><a href="https://www.index.hr/oglasi/" property="v:title" rel="v:url">Index Oglasi</a></li>
# <li typeof="v:Breadcrumb">
# <a href="https://www.index.hr/oglasi/auto-moto/gid/1" property="v:title" rel="v:url">Auto-moto</a>
# </li>
# <li typeof="v:Breadcrumb">
# <a href="https://www.index.hr/oglasi/osobni-automobili/gid/27" property="v:title" rel="v:url">Osobni automobili</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="page_header" style="background-image: url(https://www.index.hr/oglasi/userdocsimages/kategorije/auto.jpg);">
# <div class="container">
# <div class="rezultati_header">
# <h1>Osobni automobili</h1>
# <div>pronađeno <strong>26.220</strong> oglasa</div>
# <div class="change_view">
# <ul>
# <li class="hide-on-large-only"><a class="btn btn-blue show_filters" href="javascript:;">Filteri</a></li>
# <li>
# <select class="select_replacement2" id="sortby" name="sortby">
# <option selected="" value="1">Najnoviji oglasi</option>
# <option value="2">Najviša cijena</option>
# ...
# </ul>
# <span class="price"><span>30.513 €</span> ~ 229.900 kn</span></span>
# </span>
# </a>
# </div>
# <div class="OglasiRezHolder">
# <a class="result" href="https://www.index.hr/oglasi/bmw-serija-2-gran-tourer-216i--navigacija-led-/oid/3679197">
# <figure class="result_photo" data-x="2">
# <img alt="BMW serija 2 Gran Tourer 216i *NAVIGACIJA,LED*" src="https://www.index.hr/oglasi/userdocsimages/oglas/_2022//10//8///3679197/4980_20221125011301334_0_.jpg?preset=oglas-slika-view"/>
# </figure>
# <span class="result_body">
# <span class="head">
# <span class="title px18">
# BMW serija 2 Gran Tourer 216i *NAVIGACIJA,LED*
# <span class="addFavorit icon-heart tooltip_bottom" title="Spremi oglas">
# </span>
# </span>
# <span class="lead" data-fff="bb">Vozilo u sustavu PDV-a.Trans Auto d.o.o.Avenija Dubrava 264, 10040Tel: +385 1 6395 444Fax: +385 1 6395 445Mail : sven@tr</span>
# <ul class="tags hide-on-small-only"><li>
# Godište
#  :
# 2019
# </li>
# <li>
# km
#  :
# 118.672
# </li>
# <li>Starost : Rabljeno</li>
# <li>
# kW
#  :
# 80
# </li>
# <li>
# Godina modela
#  :
# 0
# </li>
# </ul>
# </span>
# <span class="foot">
# <ul class="info">
# <li class="icon-marker">Grad Zagreb</li>
# <li class="icon-time">Objava  08.10.2022.</li>
# </ul>
# <span class="price"><span>18.568 €</span> ~ 139.900 kn</span></span>
# </span>
# </a>
# </div>
# <div class="OglasiRezHolder">
# <a class="result" href="https://www.index.hr/oglasi/mercedes-benz-a-klasa-180d-automatik--led--kamera-/oid/3679195">
# <figure class="result_photo" data-x="2">
# <img alt="Mercedes-Benz A-klasa 180d AUTOMATIK *LED, KAMERA*" src="https://www.index.hr/oglasi/userdocsimages/oglas/_2022//10//8///3679195/4983_20221008021257292_0_.jpg?preset=oglas-slika-view"/>
# </figure>
# <span class="result_body">
# <span class="head">
# <span class="title px18">
# Mercedes-Benz A-klasa 180d AUTOMATIK *LED, KAMERA*
# <span class="addFavorit icon-heart tooltip_bottom" title="Spremi oglas">
# </span>
# </span>
# <span class="lead" data-fff="bb">Vozilo u sustavu PDV-a.Trans Auto d.o.o.Avenija Dubrava 264, 10040Tel: +385 1 6395 444Fax: +385 1 6395 445Mail : sven@tr</span>
# <ul class="tags hide-on-small-only"><li>
# Godište
#  :
# 2019
# </li>
# <li>
# km
#  :
# 91.471
# </li>
# <li>Starost : Rabljeno</li>
# <li>
# kW
#  :
# 85
# </li>
# <li>
# Godina modela
#  :
# 0
# </li>
# </ul>
# </span>
# <span class="foot">
# <ul class="info">
# <li class="icon-marker">Grad Zagreb</li>
# <li class="icon-time">Objava  08.10.2022.</li>
# </ul>
# <span class="price"><span>27.859 €</span> ~ 209.900 kn</span></span>
# </span>
# </a>
# </div>
# <div class="OglasiRezHolder">
# <a class="result" href="https://www.index.hr/oglasi/kia-xceed-1-6-crdi-isg-premium-dct7/oid/3679182">
# <figure class="result_photo" data-x="2">
# <img alt="KIA XCeed 1.6 CRDI ISG PREMIUM DCT7" src="https://www.index.hr/oglasi/userdocsimages/oglas/_2022//10//8///3679182/43867_20221117012134962_0_.jpg?preset=oglas-slika-view"/>
# </figure>
# <span class="result_body">
# <span class="head">
# <span class="title px18">
# KIA XCeed 1.6 CRDI ISG PREMIUM DCT7
# <span class="addFavorit icon-heart tooltip_bottom" title="Spremi oglas">
# </span>
# </span>
# <span class="lead" data-fff="bb">Vozilo na centralnom lageru importera, u ponudi za sva tržišta u regiji.              ZA DETALJNE INFORMACIJE, RASPOLOŽI</span>
# <ul class="tags hide-on-small-only"><li>
# Godište
#  :
# 2020
# </li>
# <li>
# km
#  :
# 11.884
# </li>
# <li>Starost : Rabljeno</li>
# <li>
# kW
#  :
# 100
# </li>
# <li>
# Godina modela
#  :
# 2020
# </li>
# </ul>
# </span>
# <span class="foot">
# <ul class="info">
# <li class="icon-marker">Grad Zagreb</li>
# <li class="icon-time">Objava  08.10.2022.</li>
# </ul>
# <span class="price"><span>32.517 €</span> ~ 244.999 kn</span></span>
# </span>
# </a>
# </div>
# <div class="OglasiRezHolder">
# <a class="result" href="https://www.index.hr/oglasi/kia-sportage-2-0-crdi-awd-gt-line/oid/3679183">
# <figure class="result_photo" data-x="2">
# <img alt="KIA Sportage 2.0 CRDI AWD GT-LINE" src="https://www.index.hr/oglasi/userdocsimages/oglas/_2022//10//8///3679183/43868_20221117012135024_0_.jpg?preset=oglas-slika-view"/>
# </figure>
# <span class="result_body">
# <span class="head">
# <span class="title px18">
# KIA Sportage 2.0 CRDI AWD GT-LINE
# <span class="addFavorit icon-heart tooltip_bottom" title="Spremi oglas">
# </span>
# </span>
# <span class="lead" data-fff="bb">Vozilo na centralnom lageru importera, u ponudi za sva tržišta u regiji.              ZA DETALJNE INFORMACIJE, RASPOLOŽI</span>
# <ul class="tags hide-on-small-only"><li>
# Godište
#  :
# 2017
# </li>
# <li>
# km
#  :
# 59.017
# </li>
# <li>Starost : Rabljeno</li>
# <li>
# kW
#  :
# 136
# </li>
# <li>
# Godina modela
#  :
# 2017
# </li>
# </ul>
# </span>
# <span class="foot">
# <ul class="info">
# <li class="icon-marker">Grad Zagreb</li>
# <li class="icon-time">Objava  08.10.2022.</li>
# </ul>
# <span class="price"><span>31.190 €</span> ~ 234.999 kn</span></span>
# </span>
# </a>
# </div>
# <div class="oglasiHolderBanners OglasiRezHolder splitbytwobanners">
# <div class="centerBanner">
# <div data-key="6" id="div-gpt-ad-1637582004546-0oDL6" style="padding:10px; text-align:center;">
# </div>
# <div data-key="1006" id="div-gpt-ad-1637582090880-0oDL6" style="padding:10px; text-align:center;">
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix"></div>
# <div class="page_nav"><ul class="pagination">
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=1"><i class="mdi-navigation-more-horiz"></i></a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=199"> &lt; </a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=198">198</a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=199">199</a></li>
# <li class="active"><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=200">200</a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=201">201</a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=202">202</a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=201"> &gt; </a></li>
# <li><a href="/oglasi/osobni-automobili/gid/27?pojamZup=-2&amp;tipoglasa=1&amp;sortby=1&amp;elementsNum=50&amp;grad=0&amp;naselje=0&amp;cijenaod=0&amp;cijenado=46394055&amp;num=525"><i class="mdi-navigation-more-horiz"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="backToTheTopHolder">
# <img id="backToTheTopIcon" src="https://www.index.hr/oglasi/img/top.svg"/>
# </div>
# <footer>
# <div class="info hide-on-med-and-down">
# <div class="container">
# <ul>
# <li><strong>Trebate pomoć?</strong><br/>Nazovite: 01/549 4478</li>
# <li><strong>Radno vrijeme</strong><br/>Svaki dan 8-24</li>
# <li><strong>E-mail</strong><br/><a href="mailto:indexoglasi@margon.hr">indexoglasi@margon.hr</a></li>
# </ul>
# </div>
# </div>
# <div class="links hide-on-med-and-down">
# <div class="container">
# <ul>
# <li><a href="https://www.index.hr/oglasi/oglasavanje/8">Oglašavanje</a></li>
# <li><a href="https://www.index.hr/oglasi/uvjeti-koristenja/9">Uvjeti korištenja</a></li>
# <li><a href="https://www.index.hr/oglasi/pravila-koristenja/23">Pravila korištenja</a></li>
# <li><a href="https://www.index.hr/oglasi/upute-za-koristenje/16">Upute za korištenje</a></li>
# <li><a href="https://www.index.hr/oglasi/faq/12">FAQ</a></li>
# <li><a href="https://www.index.hr/oglasi/upute-za-postavljanje-videa/17">Upute za postavljanje videa</a></li>
# </ul>
# </div>
# </div>
# <div class="back_to_top">
# <a class="icon-natrag-na-vrh" href="">Natrag na vrh</a>
# </div>
# <div>
# <strong>Index Oglasi</strong> Copyright © 2017
# 			<div class="addthis_native_toolbox" data-title="INDEX OGLASI" data-url="https://www.facebook.com/iOGLASI/"></div>
# </div>
# </footer>
# <script>
#
# 	var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# 	googletag.cmd.push(function() {
#
# 				googletag.defineSlot('/21703950087/oDL1', [[300, 250], [300, 600]], 'div-gpt-ad-1488896278673-0').addService(googletag.pubads());
#
#
#
#
# 				googletag.defineSlot('/21703950087/oDL2_L', [300, 250], 'div-gpt-ad-1637581619420-0').addService(googletag.pubads());
#
#
# 				googletag.defineSlot('/21703950087/oDL2_R', [300, 250], 'div-gpt-ad-1637581691278-0').addService(googletag.pubads());
#
#
# 				googletag.defineSlot('/21703950087/oDL3_L', [300, 250], 'div-gpt-ad-1637581773667-0').addService(googletag.pubads());
#
#
# 				googletag.defineSlot('/21703950087/oDL3_R', [300, 250], 'div-gpt-ad-1637581868332-0').addService(googletag.pubads());
#
#
# 					googletag.defineSlot('/21703950087/oDL4_L', [300, 250], 'div-gpt-ad-1637582004546-0').addService(googletag.pubads());
#
#
# 					googletag.defineSlot('/21703950087/oDL4_R', [300, 250], 'div-gpt-ad-1637582090880-0').addService(googletag.pubads());
#
#
# 						googletag.defineSlot('/21703950087/oDL5', [300, 250], 'div-gpt-ad-1637582004546-0oDL5').addService(googletag.pubads());
#
#
# 						googletag.defineSlot('/21703950087/oDL5_R', [300, 250], 'div-gpt-ad-1637582090880-0oDL5').addService(googletag.pubads());
#
# 					googletag.defineSlot('/21703950087/oDL6', [300, 250], 'div-gpt-ad-1637582004546-0oDL6').addService(googletag.pubads());
#
#
# 					googletag.defineSlot('/21703950087/oDL6_R', [300, 250], 'div-gpt-ad-1637582090880-0oDL6').addService(googletag.pubads());
#
# 				    googletag.defineSlot('/21703950087/oDL_top1', [300, 250], 'div-gpt-ad-1536147600586-0').addService(googletag.pubads());
# googletag.display('div-gpt-ad-1536147600586-0');
#     googletag.defineSlot('/21703950087/oDL_top2', [300, 250], 'div-gpt-ad-1536147707699-0').addService(googletag.pubads());
# googletag.display('div-gpt-ad-1536147707699-0');
# 		googletag.display('div-gpt-ad-1637581619420-0');
# 		googletag.display('div-gpt-ad-1637581691278-0');
# 		googletag.display('div-gpt-ad-1637581773667-0');
# 		googletag.display('div-gpt-ad-1637581868332-0');
# 		googletag.display('div-gpt-ad-1637582004546-0');
# 		googletag.display('div-gpt-ad-1637582090880-0');
# 		googletag.display('div-gpt-ad-1637582004546-0oDL5');
# 		googletag.display('div-gpt-ad-1637582090880-0oDL5');
# 		googletag.display('div-gpt-ad-1637582004546-0oDL6');
# 		googletag.display('div-gpt-ad-1637582090880-0oDL6');
# googletag.display('div-gpt-ad-1488896278673-0');
#
#
#
# 		googletag.pubads().enableSingleRequest();
# 		googletag.pubads().collapseEmptyDivs();
#
#
# 			googletag.pubads().setTargeting("category", "Auto-moto");
#
#
# 		googletag.enableServices();
#
#
#
# 			googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# 				if (event.isEmpty === false) {
# 					console.log('Slot has been rendered:');
# 					console.log(event); //inspect event
# 					console.log(event.slot); //inspect slot
#
#
#
# 				}else{
# 					console.log('Slot NOT has been rendered:');
# 				}
# 			});
#
#
#
# 	});
#
# </script>
# <!-- FOOTER main css script.js -->
# <!--
# 	<div class="modal bottom-sheet obavijestNovaPravila" style="display: none; top: 10%; opacity: 1;">
# 	        <div class="modal-content">
# 	            <h4>Poštovani posjetitelji</h4>
# 	            <div class="poruka-modal">Na snazi su nova pravila o zaštiti osobnih podataka i Index Oglasi su u skladu s tim obnovili uvjete korištenja. Koristimo kolačiće (cookies) kako bi se poboljšala funkcionalnost stranice i kako biste vidjeli one oglase koji su za vas relevantni. <br/>Više o kolačićima pročitajte <a href="https://www.index.hr/oglasi/kako-koristimo-kolacice/22">ovdje.</a></div>
# 	        </div>
#
# 	        <div class="modal-footer">
#
# 	            <a href="javascript:void(0);" class="btn btn-blue pull-left bntAcceptCookiesNew" id="">Slažem se</a>
#
# 	        </div>
# 	</div>
#
# 	<div id="lean-overlay" class="" style="display: none; opacity: 0.5;"></div>
# -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script async="async" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-55f013ef7688b2bd" type="text/javascript"></script>
# <script src="/oglasi/Scripts/myScripts?v=-X8wsb9q19jNYH7r6Y_p6MOoyM---5rz6tER5-_BwDM1" type="text/javascript"></script>
# <script type="text/javascript">
# 		<!-- //--><![CDATA[//><!--
# 		var pp_gemius_identifier = 'zIg6tjA0i62fiVCEQ9oifMQLXmG_ivsXKWAbvMmvRD..r7';
# 		// lines below shouldn't be edited
# 		function gemius_pending(i) { window[i] = window[i] || function () { var x = window[i + '_pdata'] = window[i + '_pdata'] || []; x[x.length] = arguments; }; }; gemius_pending('gemius_hit'); gemius_pending('gemius_event'); gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event'); (function (d, t) { try { var gt = d.createElement(t), s = d.getElementsByTagName(t)[0], l = 'http' + ((location.protocol == 'https:') ? 's' : ''); gt.setAttribute('async', 'async'); gt.setAttribute('defer', 'defer'); gt.src = l + '://hr.hit.gemius.pl/xgemius.js'; s.parentNode.insertBefore(gt, s); } catch (e) { } })(document, 'script');
# 		//--><!]]>
# 	</script>
# <script type="text/javascript">
#
# 		$(document).ready(function(){
#
#
#
# 		});
#
#
#
#
# 		(function(h,o,t,j,a,r){
# 			h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
# 			h._hjSettings={hjid:439196,hjsv:5};
# 			a=o.getElementsByTagName('head')[0];
# 			r=o.createElement('script');r.async=1;
# 			r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# 			a.appendChild(r);
# 		})(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#
# 		<!-- Facebook Pixel Code -->
# 		!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 		n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 		n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 		document,'script','https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '337773709953418'); // Insert your pixel ID here.
# 		fbq('track', 'PageView');
#
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
# 			ga('create', 'UA-69004064-1', 'auto');
#
#
# 		ga('send', 'pageview');
#
# 	</script>
# <script type="text/javascript">
# 			/* <![CDATA[ */
# 			(function() {
# 				window.dm=window.dm||{AjaxData:[]};
# 				window.dm.AjaxEvent=function(et,d,ssid,ad){
# 				dm.AjaxData.push({et:et,d:d,ssid:ssid,ad:ad});
# 				if(typeof window.DotMetricsObj != 'undefined') {DotMetricsObj.onAjaxDataUpdate();}
# 				};
# 				var d=document,
# 				h=d.getElementsByTagName('head')[0],
# 				s=d.createElement('script');
# 				s.type='text/javascript';
# 				s.async=true;
# 				s.src='https://script.dotmetrics.net/door.js?id=12264';
# 				h.appendChild(s);
# 			}());
# 			/* ]]> */
# 		</script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=337773709953418&amp;ev=PageView&amp;noscript=1" style="display:none" width="1">
# </img></noscript>
# <!-- DO NOT MODIFY -->
# <!-- End Facebook Pixel Code -->
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"778004b40d089b7c","token":"4435aa6f0d584c21a8a03c5c6cd581e7","version":"2022.11.3","si":100}' defer="" integrity="sha512-0ahDYl866UMhKuYcW078ScMalXqtFJggm7TmlUtp0UlD4eQk0Ixfnm5ykXKvGJNFjLMoortdseTfsRT8oCfgGA==" src="https://static.cloudflareinsights.com/beacon.min.js/vaafb692b2aea4879b33c060e79fe94621666317369993"></script>
# </body>
# </html>

# %% [markdown]
# ### Rezultat - povrat

# %%
rezultat = soup.find_all('div', {'class': 'OglasiRezHolder'})   #  kreiranj varijable radi spremanja rezultata svakog automobila-objekt lista

# %%
len(rezultat)  # provjera koliko oglasda imamo unutar liste- imam na umu da unutar 'rezulatat' ima i oglasa
# Out:
# 56

# %%
rezultat[0]     #  provjera HTML sardžaja 'rezultat' ,  iz liste sa pozicije prve a ona je na '0'
# Out:
# <div class="OglasiRezHolder">
# <a class="result" href="https://www.index.hr/oglasi/nissan-micra-1-5dci/oid/3680114">
# <figure class="result_photo" data-x="2">
# <img alt="Nissan Micra 1.5dci" src="https://www.index.hr/oglasi/userdocsimages/oglas/_2022//10//8/3680114/16652446339771665244629959166524462739520221008172115-3719641761.jpg?preset=oglas-slika-view"/>
# </figure>
# <span class="result_body">
# <span class="head">
# <span class="title px18">
# Nissan Micra 1.5dci
# <span class="addFavorit icon-heart tooltip_bottom" title="Spremi oglas">
# </span>
# </span>
# <span class="lead" data-fff="bb">Auto u odlicnom stanju.</span>
# <ul class="tags hide-on-small-only"><li>
# Godište
#  :
# 2005
# </li>
# <li>
# km
#  :
# 267.000
# </li>
# <li>Starost : Rabljeno</li>
# <li>
# kW
#  :
# 48
# </li>
# </ul>
# </span>
# <span class="foot">
# <ul class="info">
# <li class="icon-marker">Sisačko-moslavačka</li>
# <li class="icon-time">Objava  08.10.2022.</li>
# </ul>
# <span class="price"><span>2.600 €</span> ~ 19.537 kn</span></span>
# </span>
# </a>
# </div>

# %%
cijena_euri = rezultat[0].find('span', {'class':'price'}).span.text  # izdvajanje texta za cijenu u eurima
cijena_euri
# Out:
# '2.600 €'

# %%
cijena_kune = rezultat[0].find('span', {'class':'price'}).span.next_sibling   # izdvajanje texta za cijenu u kunama
cijena_kune
# Out:
# ' ~ 19.537 kn'

# %% [markdown]
# ### Izdvajanje/ciljanje - željenih informacija

# %%
# Naslov 
# Godište
# Kilometraža
# Snaga
# Lokacija
# Cijena

# %% [markdown]
# ### Naslov
# #### Traženje naslova oglasa unutar rezultata-prvi oglas, pomoću .find i atributa, i čišćenje texta samog uz .get i .strip funkcije

# %%
rezultat[0].find('span', {'class':'title px18'}).get_text().strip()
# Out:
# 'Nissan Micra 1.5dci'

# %% [markdown]
# ### Godište
# ##### Ovdje mi je sve bilo baš izazovno, jer unutar 'ul' (unordered) liste imam 'li' (listu nekoliko stavki), pa svaka stavka je razdvojena ':' delimiterom tako da baš sam se namučio u potrzi riješenja, i evo jedno od koje sam skonato i primjenio-'Godište' ,'Kilometraža', 'Snaga'

# %%
#godiste = rezultat[0].find('ul')
#for li in godiste.find_all("li"):
#    print(li.text, end=" ")

# %%
lista_ul = rezultat[0].find('ul', {'class':'tags hide-on-small-only'})
lista_li = lista_ul.find_all('li')
for stavka in lista_li:
    stavkaTXT = stavka.get_text()
    #print(stavka)
    if 'Godište' in stavkaTXT:
        godiste = stavkaTXT.split()[-1]
print(godiste)
# Out:
# 2005

# %% [markdown]
# ### Kilometraža

# %%
lista_ul = rezultat[0].find('ul', {'class':'tags hide-on-small-only'})
lista_li = lista_ul.find_all('li')
for stavka in lista_li:
    stavkaTXT = stavka.get_text()
    #print(stavka)
    if 'km' in stavkaTXT:
        kilometri = stavkaTXT.split()[-1]
print(kilometri)
# Out:
# 267.000

# %% [markdown]
# ### Snaga

# %%
lista_ul = rezultat[0].find('ul', {'class':'tags hide-on-small-only'})
lista_li = lista_ul.find_all('li')
for stavka in lista_li:
    stavkaTXT = stavka.get_text()
    #print(stavka)
    if 'kW' in stavkaTXT:
        snagaKW = stavkaTXT.split()[-1]
print(snagaKW)
# Out:
# 48

# %% [markdown]
# ### Lokacija

# %%
rezultat[0].find('li', {'class':'icon-marker'}).get_text()
# Out:
# 'Sisačko-moslavačka'

# %% [markdown]
# ### Cijena

# %%
cijena_euri = rezultat[0].find('span', {'class':'price'}).span.text
cijena_euri
# Out:
# '2.600 €'

# %%
cijena_kune = rezultat[0].find('span', {'class':'price'}).span.next_sibling
cijena_kune
# Out:
# ' ~ 19.537 kn'

# %% [markdown]
# ### Stavljnje svega unutar For-Loop petlje

# %%
# Kreiranje praznih lista svih ciljanih informacija koje ću popunjavati
# 'try' i 'except' blok mi pomaže u slučaju reklama kojih ima na svkoj stranici cca 6 komada

naslov = []
godiste = []
kilometri = []
snagakW = []
lokacija = []
cijena_kn = []
cijena_Eur = []

for oglas in rezultat:
    
    # naslov
    try:
        naslov.append(oglas.find('span', {'class':'title px18'}).get_text().strip())
    except:
        naslov.append('n/a')
        
        
    # godiste
    try:
        lista_ul = oglas.find('ul', {'class':'tags hide-on-small-only'})
        lista_li = lista_ul.find_all('li')
        for stavka in lista_li:
            stavkaTXT = stavka.get_text()
            if 'Godište' in stavkaTXT:
                god = stavkaTXT.split()[-1]
        godiste.append(int(god))       
    except:
        godiste.append('n/a')    
    
    
    # kilometri
    try:
        lista_ul = oglas.find('ul', {'class':'tags hide-on-small-only'})
        lista_li = lista_ul.find_all('li')
        for stavka in lista_li:
            stavkaTXT = stavka.get_text()
            if 'km' in stavkaTXT:
                kilom = stavkaTXT.split()[-1]
        kilometri.append(str(kilom))       
    except:
        kilometri.append('n/a')    
        
    
    # snaga
    try:
        lista_ul = oglas.find('ul', {'class':'tags hide-on-small-only'})
        lista_li = lista_ul.find_all('li')
        for stavka in lista_li:
            stavkaTXT = stavka.get_text()
            if 'kW' in stavkaTXT:
                power = stavkaTXT.split()[-1]
        snagakW.append(int(power))       
    except:
        snagakW.append('n/a')    
        
    
    # lokacija
    try:
        lokacija.append(oglas.find('li', {'class':'icon-marker'}).get_text())
    except:
        lokacija.append('n/a')
        
    
    # cijena Euri
    try:
        cijena_Eur.append(oglas.find('span', {'class':'price'}).span.get_text())
    except:
        cijena_Eur.append('n/a')
    
    # cijena Kune
    try:
        cijena_kn.append(oglas.find('span', {'class':'price'}).span.next_sibling)
    except:
        cijena_kn.append('n/a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [40], line 9
#       7 snagakW = []
#       8 lokacija = []
# ----> 9 cijena_kn = int([])
#      10 cijena_Eur = []
#      12 for oglas in rezultat:
#      13
#      14     # naslov
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
cijena_kn
# Out:
# ['n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a',
#  'n/a']

# %% [markdown]
# ### Kreiranje 'pandas' podatkovnog oblika

# %%
index_HR = pd.DataFrame({'Naslov':naslov, 'Godište':godiste, 'Kilometraža':kilometri,'Snaga-kW':snagakW, 
                         'Lokacija':lokacija, 'Cijena-Eur':cijena_Eur, 'Cijena-kn':cijena_kn})

# %%
index_HR
# Out:
#                                                Naslov Godište Kilometraža  \
# 0                                 Nissan Micra 1.5dci    2005     267.000
# 1                                                 n/a     n/a         n/a
# 2                              Peugeot 308 SW 1.6 HDI    2008     335.000
# 3                              Audi A5 Coupe 2.0 Tfsi    2013     192.000
# 4                                   BMW serija 3 325i    2005     163.500
# 5                            Honda Prelude 2.0i + LPG    1998     293.115
# 6                                     Peugeot 206 HDI    2005     130.000
# 7                             BMW serija 1 120d Coupe    2009     240.000
# 8                Mercedes-Benz CLK coupe 320 Elegance    1998     185.000
# 9                       Mercedes-Benz A-klasa 160 CDI    2005     272.000
# 10                          Audi A3 1.6 TDI Sportback    2014     230.000
# 11                                                n/a     n/a         n/a
# 12                                   Volvo S60 2.4 d5    2002     280.000
# 13  Citroën C4 1,6 BlueHDi 120KS Navi.,PDC,LED,Shi...    2018     155.000
# 14                              Peugeot 206 1.1 style    2004     101.800
# 15                                  BMW serija 1 118d    2007     220.000
# 16                                   BMW serija 3 318    2010     395.000
# 17                                 Seat Ibiza 1.4 lpg    2012     210.000
# 18                            VW Polo Classic 1.9 SDI    2001     350.000
# 19                                    Audi A4 3.0 TDI    2005     290.000
# 20                            Mercedes-Benz ML 280CDI    2007     307.000
# 21                                 Ford Focus 1.6tdci    2007     234.500
# 22                                                n/a     n/a         n/a
# 23  SKUTERI 50 i 125ccm,JAKO OČUVANI I TOMOS MOPED...    2008         777
# 24                             Renault Espace 2.2 dci    2005     307.000
# 25                                 Mazda 3 2.0 Takumi    2017      68.000
# 26  BMW 520d M-Perfomance, LED, Digital Cockpit,Ko...    2017     115.000
# 27                      BMW serija 3 Touring 318D Lci    2011     210.000
# 28     Renault Twingo 1.5 dci 63kw Auto je u Imotskom    2012     166.995
# 29                    Mercedes-Benz Vito 112 cdi 2008    2008     290.000
# 30  Mercedes-Benz C-klasa Coupe Coupe C 220 D - 2....    2017     104.000
# 31                          Opel Astra 1.6 CDTI Sedan    2016     204.300
# 32             SEAT LEON REFERENCE 1.6 - NOVO KVAČILO    2007     180.000
# 33                                                n/a     n/a         n/a
# 34                        Renault Megane 1.5dci 110ks    2015     197.000
# 35                                  BMW serija 3 330D    2000     345.000
# 36                              AUDI A8 3.0TDI QUATRO    2010     360.000
# 37                                   Mazda 6 limuzina    2014     130.000
# 38              Opel Astra 1.4 16v,reg. 06/23,očuvana    2000     281.000
# 39  Citroën C4  1.4, - 1.VLASNIK - NIJE UVOZ - REG...    2011     145.000
# 40                           VW Passat Variant 1.6TDI    2012     210.000
# 41  Smart ForFour Prime - navi, koža, panorama, pa...    2014     123.300
# 42                                  BMW serija 1 116i    2005     162.000
# 43                             Audi A4 2.o TDI S-line    2012     265.000
# 44                                                n/a     n/a         n/a
# 45                                Mitsubishi Colt 1.3    2013     133.500
# 46                                    Toyota RAV4 2.0    2009     173.000
# 47                          VW Golf VI 1.6TDI prodaja    2012     185.000
# 48                     BMW serija 3 Gran Turismo 318d    2014     166.000
# 49                                 Smart fortwo coupe    2000     167.000
# 50  BMW serija 4 Coupe 425d Automatik *LED, Kamera...    2018     105.973
# 51     BMW serija 2 Gran Tourer 216i *NAVIGACIJA,LED*    2019     118.672
# 52  Mercedes-Benz A-klasa 180d AUTOMATIK *LED, KAM...    2019      91.471
# 53                KIA XCeed 1.6 CRDI ISG PREMIUM DCT7    2020      11.884
# 54                  KIA Sportage 2.0 CRDI AWD GT-LINE    2017      59.017
# 55                                                n/a     n/a         n/a
#
#    Snaga-kW                Lokacija Cijena-Eur Cijena-kn
# 0        48      Sisačko-moslavačka        n/a       n/a
# 1       n/a                     n/a        n/a       n/a
# 2        80        Brodsko-posavska        n/a       n/a
# 3        80        Šibensko-kninska        n/a       n/a
# 4       160        Brodsko-posavska        n/a       n/a
# 5        98    Splitsko-dalmatinska        n/a       n/a
# 6        50                     n/a        n/a       n/a
# 7       130                     n/a        n/a       n/a
# 8       160      Krapinsko-zagorska        n/a       n/a
# 9        60    Vukovarsko-srijemska        n/a       n/a
# 10       81              Zagrebačka        n/a       n/a
# 11      n/a                     n/a        n/a       n/a
# 12      120  Koprivničko-križevačka        n/a       n/a
# 13       88    Splitsko-dalmatinska        n/a       n/a
# 14       44                Istarska        n/a       n/a
# 15      105  Dubrovačko-neretvanska        n/a       n/a
# 16      100      Sisačko-moslavačka        n/a       n/a
# 17      100             Grad Zagreb        n/a       n/a
# 18       50              Zagrebačka        n/a       n/a
# 19      150              Karlovačka        n/a       n/a
# 20      140    Splitsko-dalmatinska        n/a       n/a
# 21       80             Grad Zagreb        n/a       n/a
# 22      n/a                     n/a        n/a       n/a
# 23        2             Varaždinska        n/a       n/a
# 24      110             Grad Zagreb        n/a       n/a
# 25       88      Krapinsko-zagorska        n/a       n/a
# 26      140             Grad Zagreb        n/a       n/a
# 27      105             Grad Zagreb        n/a       n/a
# 28       63                     n/a        n/a       n/a
# 29       63        Brodsko-posavska        n/a       n/a
# 30      125  Bjelovarsko-bilogorska        n/a       n/a
# 31       81  Koprivničko-križevačka        n/a       n/a
# 32       75                Istarska        n/a       n/a
# 33      n/a                     n/a        n/a       n/a
# 34       85    Vukovarsko-srijemska        n/a       n/a
# 35      135              Međimurska        n/a       n/a
# 36      154                Istarska        n/a       n/a
# 37      129              Karlovačka        n/a       n/a
# 38       66             Grad Zagreb        n/a       n/a
# 39       70             Grad Zagreb        n/a       n/a
# 40       77                     n/a        n/a       n/a
# 41       52      Primorsko-goranska        n/a       n/a
# 42       85  Dubrovačko-neretvanska        n/a       n/a
# 43      105      Sisačko-moslavačka        n/a       n/a
# 44      n/a                     n/a        n/a       n/a
# 45       70  Koprivničko-križevačka        n/a       n/a
# 46      116       Osječko-baranjska        n/a       n/a
# 47       70             Grad Zagreb        n/a       n/a
# 48      105      Krapinsko-zagorska        n/a       n/a
# 49       40             Grad Zagreb        n/a       n/a
# 50      155             Grad Zagreb        n/a       n/a
# 51       80             Grad Zagreb        n/a       n/a
# 52       85             Grad Zagreb        n/a       n/a
# 53      100             Grad Zagreb        n/a       n/a
# 54      136             Grad Zagreb        n/a       n/a
# 55      n/a                     n/a        n/a       n/a

# %% [markdown]
# #### Data Cleaning

# %%
index_HR['Cijena-kn'] = index_HR['Cijena-kn'].apply(lambda x:x.strip(' kn').strip(' ~'))  # uklanjanje simbola koji mi ne triba

# %%
index_HR['Cijena-Eur'] = index_HR['Cijena-Eur'].apply(lambda x:x.strip(' €'))

# %%
index_HR
# Out:
#                                                Naslov Godište Kilometraža  \
# 0                                 Nissan Micra 1.5dci    2005     267.000
# 1                                                 n/a     n/a         n/a
# 2                              Peugeot 308 SW 1.6 HDI    2008     335.000
# 3                              Audi A5 Coupe 2.0 Tfsi    2013     192.000
# 4                                   BMW serija 3 325i    2005     163.500
# 5                            Honda Prelude 2.0i + LPG    1998     293.115
# 6                                     Peugeot 206 HDI    2005     130.000
# 7                             BMW serija 1 120d Coupe    2009     240.000
# 8                Mercedes-Benz CLK coupe 320 Elegance    1998     185.000
# 9                       Mercedes-Benz A-klasa 160 CDI    2005     272.000
# 10                          Audi A3 1.6 TDI Sportback    2014     230.000
# 11                                                n/a     n/a         n/a
# 12                                   Volvo S60 2.4 d5    2002     280.000
# 13  Citroën C4 1,6 BlueHDi 120KS Navi.,PDC,LED,Shi...    2018     155.000
# 14                              Peugeot 206 1.1 style    2004     101.800
# 15                                  BMW serija 1 118d    2007     220.000
# 16                                   BMW serija 3 318    2010     395.000
# 17                                 Seat Ibiza 1.4 lpg    2012     210.000
# 18                            VW Polo Classic 1.9 SDI    2001     350.000
# 19                                    Audi A4 3.0 TDI    2005     290.000
# 20                            Mercedes-Benz ML 280CDI    2007     307.000
# 21                                 Ford Focus 1.6tdci    2007     234.500
# 22                                                n/a     n/a         n/a
# 23  SKUTERI 50 i 125ccm,JAKO OČUVANI I TOMOS MOPED...    2008         777
# 24                             Renault Espace 2.2 dci    2005     307.000
# 25                                 Mazda 3 2.0 Takumi    2017      68.000
# 26  BMW 520d M-Perfomance, LED, Digital Cockpit,Ko...    2017     115.000
# 27                      BMW serija 3 Touring 318D Lci    2011     210.000
# 28     Renault Twingo 1.5 dci 63kw Auto je u Imotskom    2012     166.995
# 29                    Mercedes-Benz Vito 112 cdi 2008    2008     290.000
# 30  Mercedes-Benz C-klasa Coupe Coupe C 220 D - 2....    2017     104.000
# 31                          Opel Astra 1.6 CDTI Sedan    2016     204.300
# 32             SEAT LEON REFERENCE 1.6 - NOVO KVAČILO    2007     180.000
# 33                                                n/a     n/a         n/a
# 34                        Renault Megane 1.5dci 110ks    2015     197.000
# 35                                  BMW serija 3 330D    2000     345.000
# 36                              AUDI A8 3.0TDI QUATRO    2010     360.000
# 37                                   Mazda 6 limuzina    2014     130.000
# 38              Opel Astra 1.4 16v,reg. 06/23,očuvana    2000     281.000
# 39  Citroën C4  1.4, - 1.VLASNIK - NIJE UVOZ - REG...    2011     145.000
# 40                           VW Passat Variant 1.6TDI    2012     210.000
# 41  Smart ForFour Prime - navi, koža, panorama, pa...    2014     123.300
# 42                                  BMW serija 1 116i    2005     162.000
# 43                             Audi A4 2.o TDI S-line    2012     265.000
# 44                                                n/a     n/a         n/a
# 45                                Mitsubishi Colt 1.3    2013     133.500
# 46                                    Toyota RAV4 2.0    2009     173.000
# 47                          VW Golf VI 1.6TDI prodaja    2012     185.000
# 48                     BMW serija 3 Gran Turismo 318d    2014     166.000
# 49                                 Smart fortwo coupe    2000     167.000
# 50  BMW serija 4 Coupe 425d Automatik *LED, Kamera...    2018     105.973
# 51     BMW serija 2 Gran Tourer 216i *NAVIGACIJA,LED*    2019     118.672
# 52  Mercedes-Benz A-klasa 180d AUTOMATIK *LED, KAM...    2019      91.471
# 53                KIA XCeed 1.6 CRDI ISG PREMIUM DCT7    2020      11.884
# 54                  KIA Sportage 2.0 CRDI AWD GT-LINE    2017      59.017
# 55                                                n/a     n/a         n/a
#
#    Snaga-kW                Lokacija Cijena-Eur Cijena-kn
# 0        48      Sisačko-moslavačka        n/a        /a
# 1       n/a                     n/a        n/a        /a
# 2        80        Brodsko-posavska        n/a        /a
# 3        80        Šibensko-kninska        n/a        /a
# 4       160        Brodsko-posavska        n/a        /a
# 5        98    Splitsko-dalmatinska        n/a        /a
# 6        50                     n/a        n/a        /a
# 7       130                     n/a        n/a        /a
# 8       160      Krapinsko-zagorska        n/a        /a
# 9        60    Vukovarsko-srijemska        n/a        /a
# 10       81              Zagrebačka        n/a        /a
# 11      n/a                     n/a        n/a        /a
# 12      120  Koprivničko-križevačka        n/a        /a
# 13       88    Splitsko-dalmatinska        n/a        /a
# 14       44                Istarska        n/a        /a
# 15      105  Dubrovačko-neretvanska        n/a        /a
# 16      100      Sisačko-moslavačka        n/a        /a
# 17      100             Grad Zagreb        n/a        /a
# 18       50              Zagrebačka        n/a        /a
# 19      150              Karlovačka        n/a        /a
# 20      140    Splitsko-dalmatinska        n/a        /a
# 21       80             Grad Zagreb        n/a        /a
# 22      n/a                     n/a        n/a        /a
# 23        2             Varaždinska        n/a        /a
# 24      110             Grad Zagreb        n/a        /a
# 25       88      Krapinsko-zagorska        n/a        /a
# 26      140             Grad Zagreb        n/a        /a
# 27      105             Grad Zagreb        n/a        /a
# 28       63                     n/a        n/a        /a
# 29       63        Brodsko-posavska        n/a        /a
# 30      125  Bjelovarsko-bilogorska        n/a        /a
# 31       81  Koprivničko-križevačka        n/a        /a
# 32       75                Istarska        n/a        /a
# 33      n/a                     n/a        n/a        /a
# 34       85    Vukovarsko-srijemska        n/a        /a
# 35      135              Međimurska        n/a        /a
# 36      154                Istarska        n/a        /a
# 37      129              Karlovačka        n/a        /a
# 38       66             Grad Zagreb        n/a        /a
# 39       70             Grad Zagreb        n/a        /a
# 40       77                     n/a        n/a        /a
# 41       52      Primorsko-goranska        n/a        /a
# 42       85  Dubrovačko-neretvanska        n/a        /a
# 43      105      Sisačko-moslavačka        n/a        /a
# 44      n/a                     n/a        n/a        /a
# 45       70  Koprivničko-križevačka        n/a        /a
# 46      116       Osječko-baranjska        n/a        /a
# 47       70             Grad Zagreb        n/a        /a
# 48      105      Krapinsko-zagorska        n/a        /a
# 49       40             Grad Zagreb        n/a        /a
# 50      155             Grad Zagreb        n/a        /a
# 51       80             Grad Zagreb        n/a        /a
# 52       85             Grad Zagreb        n/a        /a
# 53      100             Grad Zagreb        n/a        /a
# 54      136             Grad Zagreb        n/a        /a
# 55      n/a                     n/a        n/a        /a

# %% [markdown]
# ### Output in Excel

# %%
index_HR.to_excel('jedna_str_Index-HR.xlsx', index=False)

# %% [markdown]
# ### Part 2 - Pagination

# %%
naslov = []
godiste = []
kilometri = []
snagakW = []
lokacija = []
cijena_kn = []
cijena_Eur = []

for i in range(1,11):
    
    # webstranica unutar varijable 'webstranica'
    webstranica = "https://www.index.hr/oglasi/osobni-automobili/gid/27?pojamZup=-2&tipoglasa=1&grad=0&naselje=0&cijenaod=0&cijenado=46394055&num=200&elementsNum=50&sortby= + str(i)"
    
    # zahtjev prema sajtu
    povrat = requests.get(webstranica) 
    
    # soup objekt
    soup = BeautifulSoup(povrat.content, 'html.parser')
    
    # povrat-rezultat
    rezultat = soup.find_all('div', {'class': 'OglasiRezHolder'})
    
    
    for oglas in rezultat:
    
        # naslov
        try:
            naslov.append(oglas.find('span', {'class':'title px18'}).get_text().strip())
        except:
            naslov.append('n/a')


        # godiste
        try:
            lista_ul = oglas.find('ul', {'class':'tags hide-on-small-only'})
            lista_li = lista_ul.find_all('li')
            for stavka in lista_li:
                stavkaTXT = stavka.get_text()
                if 'Godište' in stavkaTXT:
                    god = stavkaTXT.split()[-1]
            godiste.append(int(god))       
        except:
            godiste.append('n/a')    


        # kilometri
        try:
            lista_ul = oglas.find('ul', {'class':'tags hide-on-small-only'})
            lista_li = lista_ul.find_all('li')
            for stavka in lista_li:
                stavkaTXT = stavka.get_text()
                if 'km' in stavkaTXT:
                    kilom = stavkaTXT.split()[-1]
            kilometri.append(str(kilom))       
        except:
            kilometri.append('n/a')    


        # snaga
        try:
            lista_ul = oglas.find('ul', {'class':'tags hide-on-small-only'})
            lista_li = lista_ul.find_all('li')
            for stavka in lista_li:
                stavkaTXT = stavka.get_text()
                if 'kW' in stavkaTXT:
                    power = stavkaTXT.split()[-1]
            snagakW.append(int(power))       
        except:
            snagakW.append('n/a')    


        # lokacija
        try:
            lokacija.append(oglas.find('li', {'class':'icon-marker'}).get_text())
        except:
            lokacija.append('n/a')


        # cijena Euri
        try:
            cijena_Eur.append(oglas.find('span', {'class':'price'}).span.get_text())
        except:
            cijena_Eur.append('n/a')

        # cijena Kune
        try:
            cijena_kn.append(oglas.find('span', {'class':'price'}).span.next_sibling)
        except:
            cijena_kn.append('n/a')

# %%
index_HR = pd.DataFrame({'Naslov':naslov, 'Godište':godiste, 'Kilometraža':kilometri,'Snaga-kW':snagakW, 
                         'Lokacija':lokacija, 'Cijena-Eur':cijena_Eur, 'Cijena-kn':cijena_kn})

# %%
index_HR
# Out:
#                                                 Naslov Godište Kilometraža  \
# 0                                     Fiat 500 1.3 jtd    2008     245.000
# 1                                                  n/a     n/a         n/a
# 2    Ford Focus Karavan 1.5TDCi Business - top stan...    2018     124.101
# 3                                  Nissan Micra 1.5dci    2005     267.000
# 4                               Peugeot 308 SW 1.6 HDI    2008     335.000
# ..                                                 ...     ...         ...
# 555                                 Smart fortwo coupe    2000     167.000
# 556  BMW serija 4 Coupe 425d Automatik *LED, Kamera...    2018     105.973
# 557     BMW serija 2 Gran Tourer 216i *NAVIGACIJA,LED*    2019     118.672
# 558  Mercedes-Benz A-klasa 180d AUTOMATIK *LED, KAM...    2019      91.471
# 559                                                n/a     n/a         n/a
#
#     Snaga-kW              Lokacija Cijena-Eur      Cijena-kn
# 0         55  Splitsko-dalmatinska    7.700 €    ~ 58.016 kn
# 1        n/a                   n/a        n/a            n/a
# 2         88            Zagrebačka   13.450 €   ~ 101.066 kn
# 3         48    Sisačko-moslavačka    2.600 €    ~ 19.537 kn
# 4         80      Brodsko-posavska    2.999 €    ~ 22.535 kn
# ..       ...                   ...        ...            ...
# 555       40           Grad Zagreb    1.700 €    ~ 12.809 kn
# 556      155           Grad Zagreb   30.513 €   ~ 229.900 kn
# 557       80           Grad Zagreb   18.568 €   ~ 139.900 kn
# 558       85           Grad Zagreb   27.859 €   ~ 209.900 kn
# 559      n/a                   n/a        n/a            n/a
#
# [560 rows x 7 columns]

# %% [markdown]
# ### Data clenanig

# %%
index_HR['Cijena-kn'] = index_HR['Cijena-kn'].apply(lambda x:x.strip(' kn').strip(' ~'))  # uklanjanje simbola koji mi ne triba
index_HR['Cijena-Eur'] = index_HR['Cijena-Eur'].apply(lambda x:x.strip(' €'))

# %%
index_HR
# Out:
#                                                 Naslov Godište Kilometraža  \
# 0                                     Fiat 500 1.3 jtd    2008     245.000
# 1                                                  n/a     n/a         n/a
# 2    Ford Focus Karavan 1.5TDCi Business - top stan...    2018     124.101
# 3                                  Nissan Micra 1.5dci    2005     267.000
# 4                               Peugeot 308 SW 1.6 HDI    2008     335.000
# ..                                                 ...     ...         ...
# 555                                 Smart fortwo coupe    2000     167.000
# 556  BMW serija 4 Coupe 425d Automatik *LED, Kamera...    2018     105.973
# 557     BMW serija 2 Gran Tourer 216i *NAVIGACIJA,LED*    2019     118.672
# 558  Mercedes-Benz A-klasa 180d AUTOMATIK *LED, KAM...    2019      91.471
# 559                                                n/a     n/a         n/a
#
#     Snaga-kW              Lokacija Cijena-Eur Cijena-kn
# 0         55  Splitsko-dalmatinska      7.700    58.016
# 1        n/a                   n/a        n/a        /a
# 2         88            Zagrebačka     13.450   101.066
# 3         48    Sisačko-moslavačka      2.600    19.537
# 4         80      Brodsko-posavska      2.999    22.535
# ..       ...                   ...        ...       ...
# 555       40           Grad Zagreb      1.700    12.809
# 556      155           Grad Zagreb     30.513   229.900
# 557       80           Grad Zagreb     18.568   139.900
# 558       85           Grad Zagreb     27.859   209.900
# 559      n/a                   n/a        n/a        /a
#
# [560 rows x 7 columns]

# %%
index_HR.to_excel('deste_str_Index-HR.xlsx', index=False)
